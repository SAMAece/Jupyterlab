# %%
from ase.io import read
from ase import Atoms
import numpy as np
from icet import ClusterSpace
from icet.tools.structure_generation import  generate_sqs_from_supercells
from icet.input_output.logging_tools import set_log_config


i_atoms = read("CsPbI3")
br_atoms = read("CsPbBr3")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 9
#       5 from icet.tools.structure_generation import  generate_sqs_from_supercells
#       6 from icet.input_output.logging_tools import set_log_config
# ----> 9 i_atoms = read("POSCAR_I")
#      10 br_atoms = read("POSCAR_Br")
#
# File ~/miniconda3/envs/sqs/lib/python3.10/site-packages/ase/io/formats.py:736, in read(filename, index, format, parallel, do_not_split_by_at_sign, **kwargs)
#     733     return list(_iread(filename, index, format, io, parallel=parallel,
#     734                        **kwargs))
#     735 else:
# --> 736     return next(_iread(filename, slice(index, None), format, io,
#     737                        parallel=parallel, **kwargs))
#
# File ~/miniconda3/envs/sqs/lib/python3.10/site-packages/ase/parallel.py:275, in parallel_generator.<locals>.new_generator(*args, **kwargs)
#     269 @functools.wraps(generator)
#     270 def new_generator(*args, **kwargs):
#     271     if (world.size == 1 or
#     272         args and getattr(args[0], 'serial', False) or
#     273         not kwargs.pop('parallel', True)):
#     274         # Disable:
# --> 275         for result in generator(*args, **kwargs):
#     276             yield result
#     277         return
#
# File ~/miniconda3/envs/sqs/lib/python3.10/site-packages/ase/io/formats.py:793, in _iread(filename, index, format, io, parallel, full_output, **kwargs)
#     791 if io.acceptsfd:
#     792     mode = 'rb' if io.isbinary else 'r'
# --> 793     fd = open_with_compression(filename, mode)
#     794     must_close_fd = True
#     795 else:
#
# File ~/miniconda3/envs/sqs/lib/python3.10/site-packages/ase/io/formats.py:551, in open_with_compression(filename, mode)
#     548     return lzma.open(filename, mode)
#     549 else:
#     550     # Either None or unknown string
# --> 551     return open(filename, mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'POSCAR_I'

# %%
cell_diff = (i_atoms.cell - br_atoms.cell)

# %%
print("Br ", np.diag(br_atoms.cell))
print("I ", np.diag(i_atoms.cell))

# %%
set_log_config(level='INFO')

species = [
    ["I", "Br"] if species == "Br" else [species]
    for species in br_atoms.get_chemical_symbols()
]

# %%
from pymatgen.io.ase import AseAtomsAdaptor

for i in range(1, 12):
    frac = i / 12
    new_cell = br_atoms.cell + frac * cell_diff
    
    new_atoms = Atoms(
        numbers=br_atoms.numbers,
        positions=br_atoms.positions,
        cell=new_cell,
        pbc=[True, True, True]
    )
    
    cs = ClusterSpace(new_atoms, [8.0, 4.0], species)
    target_concentrations = {'Br': (12-i)/12, 'I': i/12}
    
    supercell = new_atoms.repeat((4, 4, 4))
    
    sqs = generate_sqs_from_supercells(
        cluster_space=cs,
        supercells=[supercell],
        target_concentrations=target_concentrations,
        n_steps=60000
    )
    
    sqs = AseAtomsAdaptor().get_structure(sqs)
    sqs = sqs.get_sorted_structure()
    _ = sqs.to(filename=f"POSCAR_Br{12-i}_I{i}.vasp", fmt="vasp")
# Out:
# icet.orbit_list: INFO  Done getting matrix_of_equivalent_positions.
# icet.orbit_list: INFO  Done getting neighbor lists.
# icet.orbit_list: INFO  Transformation of matrix of equivalent positions to lattice neighbor format completed.
# icet.orbit_list: INFO  Finished construction of orbit list.
# icet.target_cluster_vector_annealing: INFO  Initializing target cluster vector annealing with 1 supercells
# icet.target_cluster_vector_annealing: INFO  MC step 0/60000 (0 accepted trials, temperature 5.000), best score: 3.812
# icet.target_cluster_vector_annealing: INFO  MC step 1000/60000 (846 accepted trials, temperature 1.861), best score: -0.726
# icet.target_cluster_vector_annealing: INFO  MC step 2000/60000 (1579 accepted trials, temperature 1.546), best score: -0.726
# icet.target_cluster_vector_annealing: INFO  MC step 3000/60000 (2306 accepted trials, temperature 1.362), best score: -0.737
# icet.target_cluster_vector_annealing: INFO  MC step 4000/60000 (3022 accepted trials, temperature 1.231), best score: -0.737
# icet.target_cluster_vector_annealing: INFO  MC step 5000/60000 (3633 accepted trials, temperature 1.130), best score: -0.976
# icet.target_cluster_vector_annealing: INFO  MC step 6000/60000 (4265 accepted trials, temperature 1.047), best score: -0.976
# icet.target_cluster_vector_annealing: INFO  MC step 7000/60000 (4887 accepted trials, temperature 0.977), best score: -0.976
# icet.target_cluster_vector_annealing: INFO  MC step 8000/60000 (5479 accepted trials, temperature 0.917), best score: -0.976
# icet.target_cluster_vector_annealing: INFO  MC step 9000/60000 (6060 accepted trials, temperature 0.863), best score: -0.976
# icet.target_cluster_vector_annealing: INFO  MC step 10000/60000 (6575 accepted trials, temperature 0.815), best score: -0.976
# icet.target_cluster_vector_annealing: INFO  MC step 11000/60000 (7096 accepted trials, temperature 0.772), best score: -0.976
# icet.target_cluster_vector_annealing: INFO  MC step 12000/60000 (7592 accepted trials, temperature 0.732), best score: -0.976
# icet.target_cluster_vector_annealing: INFO  MC step 13000/60000 (8090 accepted trials, temperature 0.696), best score: -0.976
# icet.target_cluster_vector_annealing: INFO  MC step 14000/60000 (8570 accepted trials, temperature 0.662), best score: -0.976
# icet.target_cluster_vector_annealing: INFO  MC step 15000/60000 (8987 accepted trials, temperature 0.631), best score: -0.976
# icet.target_cluster_vector_annealing: INFO  MC step 16000/60000 (9410 accepted trials, temperature 0.602), best score: -0.976
# icet.target_cluster_vector_annealing: INFO  MC step 17000/60000 (9821 accepted trials, temperature 0.574), best score: -0.976
# icet.target_cluster_vector_annealing: INFO  MC step 18000/60000 (10248 accepted trials, temperature 0.548), best score: -0.976
# icet.target_cluster_vector_annealing: INFO  MC step 19000/60000 (10667 accepted trials, temperature 0.523), best score: -1.015
# icet.target_cluster_vector_annealing: INFO  MC step 20000/60000 (11059 accepted trials, temperature 0.500), best score: -1.015
# icet.target_cluster_vector_annealing: INFO  MC step 21000/60000 (11429 accepted trials, temperature 0.478), best score: -1.015
# icet.target_cluster_vector_annealing: INFO  MC step 22000/60000 (11794 accepted trials, temperature 0.457), best score: -1.015
# icet.target_cluster_vector_annealing: INFO  MC step 23000/60000 (12149 accepted trials, temperature 0.437), best score: -1.015
# icet.target_cluster_vector_annealing: INFO  MC step 24000/60000 (12555 accepted trials, temperature 0.417), best score: -1.270
# icet.target_cluster_vector_annealing: INFO  MC step 25000/60000 (12914 accepted trials, temperature 0.399), best score: -1.270
# icet.target_cluster_vector_annealing: INFO  MC step 26000/60000 (13233 accepted trials, temperature 0.381), best score: -1.284
# icet.target_cluster_vector_annealing: INFO  MC step 27000/60000 (13591 accepted trials, temperature 0.364), best score: -1.284
# icet.target_cluster_vector_annealing: INFO  MC step 28000/60000 (13922 accepted trials, temperature 0.347), best score: -1.284
# icet.target_cluster_vector_annealing: INFO  MC step 29000/60000 (14266 accepted trials, temperature 0.331), best score: -1.284
# icet.target_cluster_vector_annealing: INFO  MC step 30000/60000 (14590 accepted trials, temperature 0.316), best score: -1.284
# icet.target_cluster_vector_annealing: INFO  MC step 31000/60000 (14903 accepted trials, temperature 0.301), best score: -1.284
# icet.target_cluster_vector_annealing: INFO  MC step 32000/60000 (15172 accepted trials, temperature 0.287), best score: -1.284
# icet.target_cluster_vector_annealing: INFO  MC step 33000/60000 (15470 accepted trials, temperature 0.273), best score: -1.284
# icet.target_cluster_vector_annealing: INFO  MC step 34000/60000 (15730 accepted trials, temperature 0.259), best score: -1.284
# icet.target_cluster_vector_annealing: INFO  MC step 35000/60000 (15994 accepted trials, temperature 0.246), best score: -1.284
# icet.target_cluster_vector_annealing: INFO  MC step 36000/60000 (16255 accepted trials, temperature 0.233), best score: -1.284
# icet.target_cluster_vector_annealing: INFO  MC step 37000/60000 (16514 accepted trials, temperature 0.221), best score: -1.284
# icet.target_cluster_vector_annealing: INFO  MC step 38000/60000 (16789 accepted trials, temperature 0.209), best score: -1.284
# icet.target_cluster_vector_annealing: INFO  MC step 39000/60000 (17059 accepted trials, temperature 0.197), best score: -1.284
# icet.target_cluster_vector_annealing: INFO  MC step 40000/60000 (17261 accepted trials, temperature 0.185), best score: -1.284
# icet.target_cluster_vector_annealing: INFO  MC step 41000/60000 (17495 accepted trials, temperature 0.174), best score: -1.284
# icet.target_cluster_vector_annealing: INFO  MC step 42000/60000 (17729 accepted trials, temperature 0.163), best score: -1.284
# icet.target_cluster_vector_annealing: INFO  MC step 43000/60000 (17944 accepted trials, temperature 0.152), best score: -1.284
# icet.target_cluster_vector_annealing: INFO  MC step 44000/60000 (18147 accepted trials, temperature 0.142), best score: -1.284
# icet.target_cluster_vector_annealing: INFO  MC step 45000/60000 (18318 accepted trials, temperature 0.132), best score: -1.351
# icet.target_cluster_vector_annealing: INFO  MC step 46000/60000 (18465 accepted trials, temperature 0.122), best score: -1.351
# icet.target_cluster_vector_annealing: INFO  MC step 47000/60000 (18650 accepted trials, temperature 0.112), best score: -1.410
# icet.target_cluster_vector_annealing: INFO  MC step 48000/60000 (18803 accepted trials, temperature 0.102), best score: -1.410
# icet.target_cluster_vector_annealing: INFO  MC step 49000/60000 (18940 accepted trials, temperature 0.093), best score: -1.410
# icet.target_cluster_vector_annealing: INFO  MC step 50000/60000 (19071 accepted trials, temperature 0.084), best score: -1.410
# icet.target_cluster_vector_annealing: INFO  MC step 51000/60000 (19206 accepted trials, temperature 0.075), best score: -1.410
# icet.target_cluster_vector_annealing: INFO  MC step 52000/60000 (19284 accepted trials, temperature 0.066), best score: -1.453
# icet.target_cluster_vector_annealing: INFO  MC step 53000/60000 (19309 accepted trials, temperature 0.057), best score: -2.270
# icet.target_cluster_vector_annealing: INFO  MC step 54000/60000 (19317 accepted trials, temperature 0.049), best score: -2.859
# icet.target_cluster_vector_annealing: INFO  MC step 55000/60000 (19323 accepted trials, temperature 0.041), best score: -2.859
# icet.target_cluster_vector_annealing: INFO  MC step 56000/60000 (19323 accepted trials, temperature 0.032), best score: -2.859
# icet.target_cluster_vector_annealing: INFO  MC step 57000/60000 (19326 accepted trials, temperature 0.024), best score: -2.859
# icet.target_cluster_vector_annealing: INFO  MC step 58000/60000 (19327 accepted trials, temperature 0.016), best score: -2.859
# icet.target_cluster_vector_annealing: INFO  MC step 59000/60000 (19329 accepted trials, temperature 0.009), best score: -2.859
# icet.orbit_list: INFO  Done getting matrix_of_equivalent_positions.
# icet.orbit_list: INFO  Done getting neighbor lists.
# icet.orbit_list: INFO  Transformation of matrix of equivalent positions to lattice neighbor format completed.
# icet.orbit_list: INFO  Finished construction of orbit list.
# icet.target_cluster_vector_annealing: INFO  Initializing target cluster vector annealing with 1 supercells
# icet.target_cluster_vector_annealing: INFO  MC step 0/60000 (0 accepted trials, temperature 5.000), best score: 4.125
# icet.target_cluster_vector_annealing: INFO  MC step 1000/60000 (874 accepted trials, temperature 1.861), best score: 0.903
# icet.target_cluster_vector_annealing: INFO  MC step 2000/60000 (1680 accepted trials, temperature 1.546), best score: 0.591
# icet.target_cluster_vector_annealing: INFO  MC step 3000/60000 (2448 accepted trials, temperature 1.362), best score: 0.007
# icet.target_cluster_vector_annealing: INFO  MC step 4000/60000 (3175 accepted trials, temperature 1.231), best score: 0.007
# icet.target_cluster_vector_annealing: INFO  MC step 5000/60000 (3912 accepted trials, temperature 1.130), best score: 0.007
# icet.target_cluster_vector_annealing: INFO  MC step 6000/60000 (4575 accepted trials, temperature 1.047), best score: 0.007
# icet.target_cluster_vector_annealing: INFO  MC step 7000/60000 (5241 accepted trials, temperature 0.977), best score: 0.007
# icet.target_cluster_vector_annealing: INFO  MC step 8000/60000 (5853 accepted trials, temperature 0.917), best score: 0.007
# icet.target_cluster_vector_annealing: INFO  MC step 9000/60000 (6425 accepted trials, temperature 0.863), best score: 0.007
# icet.target_cluster_vector_annealing: INFO  MC step 10000/60000 (6980 accepted trials, temperature 0.815), best score: 0.007
# icet.target_cluster_vector_annealing: INFO  MC step 11000/60000 (7517 accepted trials, temperature 0.772), best score: 0.007
# icet.target_cluster_vector_annealing: INFO  MC step 12000/60000 (8047 accepted trials, temperature 0.732), best score: 0.007
# icet.target_cluster_vector_annealing: INFO  MC step 13000/60000 (8511 accepted trials, temperature 0.696), best score: 0.007
# icet.target_cluster_vector_annealing: INFO  MC step 14000/60000 (8969 accepted trials, temperature 0.662), best score: -0.118
# icet.target_cluster_vector_annealing: INFO  MC step 15000/60000 (9430 accepted trials, temperature 0.631), best score: -0.118
# icet.target_cluster_vector_annealing: INFO  MC step 16000/60000 (9893 accepted trials, temperature 0.602), best score: -0.118
# icet.target_cluster_vector_annealing: INFO  MC step 17000/60000 (10307 accepted trials, temperature 0.574), best score: -0.118
# icet.target_cluster_vector_annealing: INFO  MC step 18000/60000 (10700 accepted trials, temperature 0.548), best score: -0.118
# icet.target_cluster_vector_annealing: INFO  MC step 19000/60000 (11134 accepted trials, temperature 0.523), best score: -0.118
# icet.target_cluster_vector_annealing: INFO  MC step 20000/60000 (11456 accepted trials, temperature 0.500), best score: -0.118
# icet.target_cluster_vector_annealing: INFO  MC step 21000/60000 (11807 accepted trials, temperature 0.478), best score: -0.118
# icet.target_cluster_vector_annealing: INFO  MC step 22000/60000 (12166 accepted trials, temperature 0.457), best score: -0.118
# icet.target_cluster_vector_annealing: INFO  MC step 23000/60000 (12490 accepted trials, temperature 0.437), best score: -0.118
# icet.target_cluster_vector_annealing: INFO  MC step 24000/60000 (12803 accepted trials, temperature 0.417), best score: -0.118
# icet.target_cluster_vector_annealing: INFO  MC step 25000/60000 (13105 accepted trials, temperature 0.399), best score: -0.118
# icet.target_cluster_vector_annealing: INFO  MC step 26000/60000 (13416 accepted trials, temperature 0.381), best score: -0.118
# icet.target_cluster_vector_annealing: INFO  MC step 27000/60000 (13715 accepted trials, temperature 0.364), best score: -0.118
# icet.target_cluster_vector_annealing: INFO  MC step 28000/60000 (14032 accepted trials, temperature 0.347), best score: -0.118
# icet.target_cluster_vector_annealing: INFO  MC step 29000/60000 (14340 accepted trials, temperature 0.331), best score: -0.118
# icet.target_cluster_vector_annealing: INFO  MC step 30000/60000 (14640 accepted trials, temperature 0.316), best score: -0.118
# icet.target_cluster_vector_annealing: INFO  MC step 31000/60000 (14932 accepted trials, temperature 0.301), best score: -0.243
# icet.target_cluster_vector_annealing: INFO  MC step 32000/60000 (15182 accepted trials, temperature 0.287), best score: -0.243
# icet.target_cluster_vector_annealing: INFO  MC step 33000/60000 (15446 accepted trials, temperature 0.273), best score: -0.284
# icet.target_cluster_vector_annealing: INFO  MC step 34000/60000 (15714 accepted trials, temperature 0.259), best score: -0.284
# icet.target_cluster_vector_annealing: INFO  MC step 35000/60000 (15949 accepted trials, temperature 0.246), best score: -0.284
# icet.target_cluster_vector_annealing: INFO  MC step 36000/60000 (16209 accepted trials, temperature 0.233), best score: -0.284
# icet.target_cluster_vector_annealing: INFO  MC step 37000/60000 (16473 accepted trials, temperature 0.221), best score: -0.284
# icet.target_cluster_vector_annealing: INFO  MC step 38000/60000 (16697 accepted trials, temperature 0.209), best score: -0.284
# icet.target_cluster_vector_annealing: INFO  MC step 39000/60000 (16911 accepted trials, temperature 0.197), best score: -0.328
# icet.target_cluster_vector_annealing: INFO  MC step 40000/60000 (17147 accepted trials, temperature 0.185), best score: -0.328
# icet.target_cluster_vector_annealing: INFO  MC step 41000/60000 (17323 accepted trials, temperature 0.174), best score: -0.368
# icet.target_cluster_vector_annealing: INFO  MC step 42000/60000 (17525 accepted trials, temperature 0.163), best score: -0.368
# icet.target_cluster_vector_annealing: INFO  MC step 43000/60000 (17699 accepted trials, temperature 0.152), best score: -0.753
# icet.target_cluster_vector_annealing: INFO  MC step 44000/60000 (17877 accepted trials, temperature 0.142), best score: -0.753
# icet.target_cluster_vector_annealing: INFO  MC step 45000/60000 (18025 accepted trials, temperature 0.132), best score: -0.753
# icet.target_cluster_vector_annealing: INFO  MC step 46000/60000 (18178 accepted trials, temperature 0.122), best score: -0.753
# icet.target_cluster_vector_annealing: INFO  MC step 47000/60000 (18275 accepted trials, temperature 0.112), best score: -0.765
# icet.target_cluster_vector_annealing: INFO  MC step 48000/60000 (18367 accepted trials, temperature 0.102), best score: -0.765
# icet.target_cluster_vector_annealing: INFO  MC step 49000/60000 (18426 accepted trials, temperature 0.093), best score: -0.765
# icet.target_cluster_vector_annealing: INFO  MC step 50000/60000 (18492 accepted trials, temperature 0.084), best score: -0.765
# icet.target_cluster_vector_annealing: INFO  MC step 51000/60000 (18554 accepted trials, temperature 0.075), best score: -0.765
# icet.target_cluster_vector_annealing: INFO  MC step 52000/60000 (18617 accepted trials, temperature 0.066), best score: -0.765
# icet.target_cluster_vector_annealing: INFO  MC step 53000/60000 (18658 accepted trials, temperature 0.057), best score: -0.784
# icet.target_cluster_vector_annealing: INFO  MC step 54000/60000 (18669 accepted trials, temperature 0.049), best score: -1.082
# icet.target_cluster_vector_annealing: INFO  MC step 55000/60000 (18675 accepted trials, temperature 0.041), best score: -1.082
# icet.target_cluster_vector_annealing: INFO  MC step 56000/60000 (18681 accepted trials, temperature 0.032), best score: -1.174
# icet.target_cluster_vector_annealing: INFO  MC step 57000/60000 (18687 accepted trials, temperature 0.024), best score: -1.579
# icet.target_cluster_vector_annealing: INFO  MC step 58000/60000 (18687 accepted trials, temperature 0.016), best score: -1.579
# icet.target_cluster_vector_annealing: INFO  MC step 59000/60000 (18687 accepted trials, temperature 0.009), best score: -1.579
# icet.orbit_list: INFO  Done getting matrix_of_equivalent_positions.
# icet.orbit_list: INFO  Done getting neighbor lists.
# icet.orbit_list: INFO  Transformation of matrix of equivalent positions to lattice neighbor format completed.
# icet.orbit_list: INFO  Finished construction of orbit list.
# icet.target_cluster_vector_annealing: INFO  Initializing target cluster vector annealing with 1 supercells
# icet.target_cluster_vector_annealing: INFO  MC step 0/60000 (0 accepted trials, temperature 5.000), best score: 4.500
# icet.target_cluster_vector_annealing: INFO  MC step 1000/60000 (880 accepted trials, temperature 1.861), best score: 1.091
# icet.target_cluster_vector_annealing: INFO  MC step 2000/60000 (1700 accepted trials, temperature 1.546), best score: 0.966
# icet.target_cluster_vector_annealing: INFO  MC step 3000/60000 (2494 accepted trials, temperature 1.362), best score: 0.966
# icet.target_cluster_vector_annealing: INFO  MC step 4000/60000 (3235 accepted trials, temperature 1.231), best score: 0.403
# icet.target_cluster_vector_annealing: INFO  MC step 5000/60000 (3945 accepted trials, temperature 1.130), best score: 0.403
# icet.target_cluster_vector_annealing: INFO  MC step 6000/60000 (4671 accepted trials, temperature 1.047), best score: 0.403
# icet.target_cluster_vector_annealing: INFO  MC step 7000/60000 (5320 accepted trials, temperature 0.977), best score: 0.403
# icet.target_cluster_vector_annealing: INFO  MC step 8000/60000 (6006 accepted trials, temperature 0.917), best score: 0.403
# icet.target_cluster_vector_annealing: INFO  MC step 9000/60000 (6580 accepted trials, temperature 0.863), best score: 0.403
# icet.target_cluster_vector_annealing: INFO  MC step 10000/60000 (7153 accepted trials, temperature 0.815), best score: 0.403
# icet.target_cluster_vector_annealing: INFO  MC step 11000/60000 (7796 accepted trials, temperature 0.772), best score: 0.403
# icet.target_cluster_vector_annealing: INFO  MC step 12000/60000 (8291 accepted trials, temperature 0.732), best score: 0.403
# icet.target_cluster_vector_annealing: INFO  MC step 13000/60000 (8821 accepted trials, temperature 0.696), best score: 0.403
# icet.target_cluster_vector_annealing: INFO  MC step 14000/60000 (9308 accepted trials, temperature 0.662), best score: 0.403
# icet.target_cluster_vector_annealing: INFO  MC step 15000/60000 (9717 accepted trials, temperature 0.631), best score: 0.403
# icet.target_cluster_vector_annealing: INFO  MC step 16000/60000 (10174 accepted trials, temperature 0.602), best score: 0.403
# icet.target_cluster_vector_annealing: INFO  MC step 17000/60000 (10540 accepted trials, temperature 0.574), best score: 0.403
# icet.target_cluster_vector_annealing: INFO  MC step 18000/60000 (10927 accepted trials, temperature 0.548), best score: 0.403
# icet.target_cluster_vector_annealing: INFO  MC step 19000/60000 (11302 accepted trials, temperature 0.523), best score: 0.403
# icet.target_cluster_vector_annealing: INFO  MC step 20000/60000 (11639 accepted trials, temperature 0.500), best score: 0.403
# icet.target_cluster_vector_annealing: INFO  MC step 21000/60000 (11994 accepted trials, temperature 0.478), best score: 0.403
# icet.target_cluster_vector_annealing: INFO  MC step 22000/60000 (12281 accepted trials, temperature 0.457), best score: 0.403
# icet.target_cluster_vector_annealing: INFO  MC step 23000/60000 (12583 accepted trials, temperature 0.437), best score: 0.403
# icet.target_cluster_vector_annealing: INFO  MC step 24000/60000 (12847 accepted trials, temperature 0.417), best score: 0.341
# icet.target_cluster_vector_annealing: INFO  MC step 25000/60000 (13151 accepted trials, temperature 0.399), best score: 0.341
# icet.target_cluster_vector_annealing: INFO  MC step 26000/60000 (13424 accepted trials, temperature 0.381), best score: 0.341
# icet.target_cluster_vector_annealing: INFO  MC step 27000/60000 (13666 accepted trials, temperature 0.364), best score: 0.341
# icet.target_cluster_vector_annealing: INFO  MC step 28000/60000 (13960 accepted trials, temperature 0.347), best score: 0.341
# icet.target_cluster_vector_annealing: INFO  MC step 29000/60000 (14240 accepted trials, temperature 0.331), best score: 0.341
# icet.target_cluster_vector_annealing: INFO  MC step 30000/60000 (14480 accepted trials, temperature 0.316), best score: 0.341
# icet.target_cluster_vector_annealing: INFO  MC step 31000/60000 (14722 accepted trials, temperature 0.301), best score: 0.231
# icet.target_cluster_vector_annealing: INFO  MC step 32000/60000 (14934 accepted trials, temperature 0.287), best score: 0.231
# icet.target_cluster_vector_annealing: INFO  MC step 33000/60000 (15178 accepted trials, temperature 0.273), best score: 0.091
# icet.target_cluster_vector_annealing: INFO  MC step 34000/60000 (15411 accepted trials, temperature 0.259), best score: 0.091
# icet.target_cluster_vector_annealing: INFO  MC step 35000/60000 (15639 accepted trials, temperature 0.246), best score: 0.091
# icet.target_cluster_vector_annealing: INFO  MC step 36000/60000 (15863 accepted trials, temperature 0.233), best score: 0.091
# icet.target_cluster_vector_annealing: INFO  MC step 37000/60000 (16064 accepted trials, temperature 0.221), best score: 0.091
# icet.target_cluster_vector_annealing: INFO  MC step 38000/60000 (16256 accepted trials, temperature 0.209), best score: 0.091
# icet.target_cluster_vector_annealing: INFO  MC step 39000/60000 (16461 accepted trials, temperature 0.197), best score: 0.091
# icet.target_cluster_vector_annealing: INFO  MC step 40000/60000 (16622 accepted trials, temperature 0.185), best score: 0.091
# icet.target_cluster_vector_annealing: INFO  MC step 41000/60000 (16807 accepted trials, temperature 0.174), best score: -0.015
# icet.target_cluster_vector_annealing: INFO  MC step 42000/60000 (16985 accepted trials, temperature 0.163), best score: -0.015
# icet.target_cluster_vector_annealing: INFO  MC step 43000/60000 (17167 accepted trials, temperature 0.152), best score: -0.015
# icet.target_cluster_vector_annealing: INFO  MC step 44000/60000 (17313 accepted trials, temperature 0.142), best score: -0.159
# icet.target_cluster_vector_annealing: INFO  MC step 45000/60000 (17418 accepted trials, temperature 0.132), best score: -0.179
# icet.target_cluster_vector_annealing: INFO  MC step 46000/60000 (17487 accepted trials, temperature 0.122), best score: -0.331
# icet.target_cluster_vector_annealing: INFO  MC step 47000/60000 (17590 accepted trials, temperature 0.112), best score: -0.331
# icet.target_cluster_vector_annealing: INFO  MC step 48000/60000 (17652 accepted trials, temperature 0.102), best score: -0.331
# icet.target_cluster_vector_annealing: INFO  MC step 49000/60000 (17716 accepted trials, temperature 0.093), best score: -0.347
# icet.target_cluster_vector_annealing: INFO  MC step 50000/60000 (17789 accepted trials, temperature 0.084), best score: -0.347
# icet.target_cluster_vector_annealing: INFO  MC step 51000/60000 (17804 accepted trials, temperature 0.075), best score: -0.640
# icet.target_cluster_vector_annealing: INFO  MC step 52000/60000 (17824 accepted trials, temperature 0.066), best score: -0.640
# icet.target_cluster_vector_annealing: INFO  MC step 53000/60000 (17848 accepted trials, temperature 0.057), best score: -0.770
# icet.target_cluster_vector_annealing: INFO  MC step 54000/60000 (17855 accepted trials, temperature 0.049), best score: -0.770
# icet.target_cluster_vector_annealing: INFO  MC step 55000/60000 (17863 accepted trials, temperature 0.041), best score: -0.832
# icet.target_cluster_vector_annealing: INFO  MC step 56000/60000 (17870 accepted trials, temperature 0.032), best score: -0.832
# icet.target_cluster_vector_annealing: INFO  MC step 57000/60000 (17877 accepted trials, temperature 0.024), best score: -0.939
# icet.target_cluster_vector_annealing: INFO  MC step 58000/60000 (17879 accepted trials, temperature 0.016), best score: -1.101
# icet.target_cluster_vector_annealing: INFO  MC step 59000/60000 (17881 accepted trials, temperature 0.009), best score: -2.014
# icet.orbit_list: INFO  Done getting matrix_of_equivalent_positions.
# icet.orbit_list: INFO  Done getting neighbor lists.
# icet.orbit_list: INFO  Transformation of matrix of equivalent positions to lattice neighbor format completed.
# icet.orbit_list: INFO  Finished construction of orbit list.
# icet.target_cluster_vector_annealing: INFO  Initializing target cluster vector annealing with 1 supercells
# icet.target_cluster_vector_annealing: INFO  MC step 0/60000 (0 accepted trials, temperature 5.000), best score: 4.812
# icet.target_cluster_vector_annealing: INFO  MC step 1000/60000 (882 accepted trials, temperature 1.861), best score: 1.341
# icet.target_cluster_vector_annealing: INFO  MC step 2000/60000 (1706 accepted trials, temperature 1.546), best score: 1.172
# icet.target_cluster_vector_annealing: INFO  MC step 3000/60000 (2495 accepted trials, temperature 1.362), best score: 1.172
# icet.target_cluster_vector_annealing: INFO  MC step 4000/60000 (3309 accepted trials, temperature 1.231), best score: 0.715
# icet.target_cluster_vector_annealing: INFO  MC step 5000/60000 (4070 accepted trials, temperature 1.130), best score: 0.715
# icet.target_cluster_vector_annealing: INFO  MC step 6000/60000 (4777 accepted trials, temperature 1.047), best score: 0.715
# icet.target_cluster_vector_annealing: INFO  MC step 7000/60000 (5471 accepted trials, temperature 0.977), best score: 0.715
# icet.target_cluster_vector_annealing: INFO  MC step 8000/60000 (6082 accepted trials, temperature 0.917), best score: 0.715
# icet.target_cluster_vector_annealing: INFO  MC step 9000/60000 (6710 accepted trials, temperature 0.863), best score: 0.715
# icet.target_cluster_vector_annealing: INFO  MC step 10000/60000 (7338 accepted trials, temperature 0.815), best score: 0.715
# icet.target_cluster_vector_annealing: INFO  MC step 11000/60000 (7866 accepted trials, temperature 0.772), best score: 0.715
# icet.target_cluster_vector_annealing: INFO  MC step 12000/60000 (8404 accepted trials, temperature 0.732), best score: 0.715
# icet.target_cluster_vector_annealing: INFO  MC step 13000/60000 (8989 accepted trials, temperature 0.696), best score: 0.715
# icet.target_cluster_vector_annealing: INFO  MC step 14000/60000 (9507 accepted trials, temperature 0.662), best score: 0.715
# icet.target_cluster_vector_annealing: INFO  MC step 15000/60000 (9999 accepted trials, temperature 0.631), best score: 0.028
# icet.target_cluster_vector_annealing: INFO  MC step 16000/60000 (10489 accepted trials, temperature 0.602), best score: 0.028
# icet.target_cluster_vector_annealing: INFO  MC step 17000/60000 (10942 accepted trials, temperature 0.574), best score: 0.028
# icet.target_cluster_vector_annealing: INFO  MC step 18000/60000 (11339 accepted trials, temperature 0.548), best score: 0.028
# icet.target_cluster_vector_annealing: INFO  MC step 19000/60000 (11683 accepted trials, temperature 0.523), best score: 0.028
# icet.target_cluster_vector_annealing: INFO  MC step 20000/60000 (12008 accepted trials, temperature 0.500), best score: 0.028
# icet.target_cluster_vector_annealing: INFO  MC step 21000/60000 (12364 accepted trials, temperature 0.478), best score: 0.028
# icet.target_cluster_vector_annealing: INFO  MC step 22000/60000 (12666 accepted trials, temperature 0.457), best score: 0.028
# icet.target_cluster_vector_annealing: INFO  MC step 23000/60000 (12984 accepted trials, temperature 0.437), best score: 0.028
# icet.target_cluster_vector_annealing: INFO  MC step 24000/60000 (13281 accepted trials, temperature 0.417), best score: 0.028
# icet.target_cluster_vector_annealing: INFO  MC step 25000/60000 (13541 accepted trials, temperature 0.399), best score: 0.028
# icet.target_cluster_vector_annealing: INFO  MC step 26000/60000 (13816 accepted trials, temperature 0.381), best score: 0.028
# icet.target_cluster_vector_annealing: INFO  MC step 27000/60000 (14114 accepted trials, temperature 0.364), best score: 0.028
# icet.target_cluster_vector_annealing: INFO  MC step 28000/60000 (14372 accepted trials, temperature 0.347), best score: 0.028
# icet.target_cluster_vector_annealing: INFO  MC step 29000/60000 (14635 accepted trials, temperature 0.331), best score: 0.028
# icet.target_cluster_vector_annealing: INFO  MC step 30000/60000 (14864 accepted trials, temperature 0.316), best score: 0.028
# icet.target_cluster_vector_annealing: INFO  MC step 31000/60000 (15094 accepted trials, temperature 0.301), best score: 0.028
# icet.target_cluster_vector_annealing: INFO  MC step 32000/60000 (15315 accepted trials, temperature 0.287), best score: 0.028
# icet.target_cluster_vector_annealing: INFO  MC step 33000/60000 (15525 accepted trials, temperature 0.273), best score: 0.028
# icet.target_cluster_vector_annealing: INFO  MC step 34000/60000 (15748 accepted trials, temperature 0.259), best score: 0.028
# icet.target_cluster_vector_annealing: INFO  MC step 35000/60000 (15976 accepted trials, temperature 0.246), best score: 0.028
# icet.target_cluster_vector_annealing: INFO  MC step 36000/60000 (16179 accepted trials, temperature 0.233), best score: 0.028
# icet.target_cluster_vector_annealing: INFO  MC step 37000/60000 (16382 accepted trials, temperature 0.221), best score: 0.028
# icet.target_cluster_vector_annealing: INFO  MC step 38000/60000 (16586 accepted trials, temperature 0.209), best score: 0.028
# icet.target_cluster_vector_annealing: INFO  MC step 39000/60000 (16762 accepted trials, temperature 0.197), best score: 0.028
# icet.target_cluster_vector_annealing: INFO  MC step 40000/60000 (16932 accepted trials, temperature 0.185), best score: 0.028
# icet.target_cluster_vector_annealing: INFO  MC step 41000/60000 (17094 accepted trials, temperature 0.174), best score: 0.028
# icet.target_cluster_vector_annealing: INFO  MC step 42000/60000 (17233 accepted trials, temperature 0.163), best score: 0.028
# icet.target_cluster_vector_annealing: INFO  MC step 43000/60000 (17370 accepted trials, temperature 0.152), best score: 0.028
# icet.target_cluster_vector_annealing: INFO  MC step 44000/60000 (17487 accepted trials, temperature 0.142), best score: 0.028
# icet.target_cluster_vector_annealing: INFO  MC step 45000/60000 (17613 accepted trials, temperature 0.132), best score: 0.028
# icet.target_cluster_vector_annealing: INFO  MC step 46000/60000 (17743 accepted trials, temperature 0.122), best score: -0.160
# icet.target_cluster_vector_annealing: INFO  MC step 47000/60000 (17840 accepted trials, temperature 0.112), best score: -0.160
# icet.target_cluster_vector_annealing: INFO  MC step 48000/60000 (17929 accepted trials, temperature 0.102), best score: -0.160
# icet.target_cluster_vector_annealing: INFO  MC step 49000/60000 (18006 accepted trials, temperature 0.093), best score: -0.160
# icet.target_cluster_vector_annealing: INFO  MC step 50000/60000 (18080 accepted trials, temperature 0.084), best score: -0.160
# icet.target_cluster_vector_annealing: INFO  MC step 51000/60000 (18125 accepted trials, temperature 0.075), best score: -0.453
# icet.target_cluster_vector_annealing: INFO  MC step 52000/60000 (18140 accepted trials, temperature 0.066), best score: -0.453
# icet.target_cluster_vector_annealing: INFO  MC step 53000/60000 (18147 accepted trials, temperature 0.057), best score: -0.523
# icet.target_cluster_vector_annealing: INFO  MC step 54000/60000 (18149 accepted trials, temperature 0.049), best score: -0.523
# icet.target_cluster_vector_annealing: INFO  MC step 55000/60000 (18158 accepted trials, temperature 0.041), best score: -0.523
# icet.target_cluster_vector_annealing: INFO  MC step 56000/60000 (18164 accepted trials, temperature 0.032), best score: -0.707
# icet.target_cluster_vector_annealing: INFO  MC step 57000/60000 (18166 accepted trials, temperature 0.024), best score: -0.707
# icet.target_cluster_vector_annealing: INFO  MC step 58000/60000 (18169 accepted trials, temperature 0.016), best score: -0.957
# icet.target_cluster_vector_annealing: INFO  MC step 59000/60000 (18169 accepted trials, temperature 0.009), best score: -0.957
# icet.orbit_list: INFO  Done getting matrix_of_equivalent_positions.
# icet.orbit_list: INFO  Done getting neighbor lists.
# icet.orbit_list: INFO  Transformation of matrix of equivalent positions to lattice neighbor format completed.
# icet.orbit_list: INFO  Finished construction of orbit list.
# icet.target_cluster_vector_annealing: INFO  Initializing target cluster vector annealing with 1 supercells
# icet.target_cluster_vector_annealing: INFO  MC step 0/60000 (0 accepted trials, temperature 5.000), best score: 7.000
# icet.target_cluster_vector_annealing: INFO  MC step 1000/60000 (895 accepted trials, temperature 1.861), best score: 1.262
# icet.target_cluster_vector_annealing: INFO  MC step 2000/60000 (1733 accepted trials, temperature 1.546), best score: 1.074
# icet.target_cluster_vector_annealing: INFO  MC step 3000/60000 (2524 accepted trials, temperature 1.362), best score: 0.903
# icet.target_cluster_vector_annealing: INFO  MC step 4000/60000 (3230 accepted trials, temperature 1.231), best score: 0.903
# icet.target_cluster_vector_annealing: INFO  MC step 5000/60000 (3961 accepted trials, temperature 1.130), best score: 0.903
# icet.target_cluster_vector_annealing: INFO  MC step 6000/60000 (4647 accepted trials, temperature 1.047), best score: 0.778
# icet.target_cluster_vector_annealing: INFO  MC step 7000/60000 (5296 accepted trials, temperature 0.977), best score: 0.778
# icet.target_cluster_vector_annealing: INFO  MC step 8000/60000 (5880 accepted trials, temperature 0.917), best score: 0.778
# icet.target_cluster_vector_annealing: INFO  MC step 9000/60000 (6503 accepted trials, temperature 0.863), best score: 0.778
# icet.target_cluster_vector_annealing: INFO  MC step 10000/60000 (7022 accepted trials, temperature 0.815), best score: 0.778
# icet.target_cluster_vector_annealing: INFO  MC step 11000/60000 (7541 accepted trials, temperature 0.772), best score: 0.778
# icet.target_cluster_vector_annealing: INFO  MC step 12000/60000 (8016 accepted trials, temperature 0.732), best score: 0.778
# icet.target_cluster_vector_annealing: INFO  MC step 13000/60000 (8439 accepted trials, temperature 0.696), best score: 0.778
# icet.target_cluster_vector_annealing: INFO  MC step 14000/60000 (8947 accepted trials, temperature 0.662), best score: 0.778
# icet.target_cluster_vector_annealing: INFO  MC step 15000/60000 (9395 accepted trials, temperature 0.631), best score: 0.778
# icet.target_cluster_vector_annealing: INFO  MC step 16000/60000 (9806 accepted trials, temperature 0.602), best score: 0.778
# icet.target_cluster_vector_annealing: INFO  MC step 17000/60000 (10151 accepted trials, temperature 0.574), best score: 0.778
# icet.target_cluster_vector_annealing: INFO  MC step 18000/60000 (10606 accepted trials, temperature 0.548), best score: 0.403
# icet.target_cluster_vector_annealing: INFO  MC step 19000/60000 (11074 accepted trials, temperature 0.523), best score: 0.403
# icet.target_cluster_vector_annealing: INFO  MC step 20000/60000 (11383 accepted trials, temperature 0.500), best score: 0.341
# icet.target_cluster_vector_annealing: INFO  MC step 21000/60000 (11704 accepted trials, temperature 0.478), best score: 0.341
# icet.target_cluster_vector_annealing: INFO  MC step 22000/60000 (11996 accepted trials, temperature 0.457), best score: 0.341
# icet.target_cluster_vector_annealing: INFO  MC step 23000/60000 (12316 accepted trials, temperature 0.437), best score: 0.341
# icet.target_cluster_vector_annealing: INFO  MC step 24000/60000 (12563 accepted trials, temperature 0.417), best score: 0.341
# icet.target_cluster_vector_annealing: INFO  MC step 25000/60000 (12870 accepted trials, temperature 0.399), best score: 0.341
# icet.target_cluster_vector_annealing: INFO  MC step 26000/60000 (13227 accepted trials, temperature 0.381), best score: 0.341
# icet.target_cluster_vector_annealing: INFO  MC step 27000/60000 (13470 accepted trials, temperature 0.364), best score: 0.341
# icet.target_cluster_vector_annealing: INFO  MC step 28000/60000 (13744 accepted trials, temperature 0.347), best score: 0.341
# icet.target_cluster_vector_annealing: INFO  MC step 29000/60000 (14016 accepted trials, temperature 0.331), best score: 0.341
# icet.target_cluster_vector_annealing: INFO  MC step 30000/60000 (14265 accepted trials, temperature 0.316), best score: 0.341
# icet.target_cluster_vector_annealing: INFO  MC step 31000/60000 (14488 accepted trials, temperature 0.301), best score: 0.341
# icet.target_cluster_vector_annealing: INFO  MC step 32000/60000 (14736 accepted trials, temperature 0.287), best score: 0.341
# icet.target_cluster_vector_annealing: INFO  MC step 33000/60000 (14996 accepted trials, temperature 0.273), best score: 0.341
# icet.target_cluster_vector_annealing: INFO  MC step 34000/60000 (15225 accepted trials, temperature 0.259), best score: 0.341
# icet.target_cluster_vector_annealing: INFO  MC step 35000/60000 (15426 accepted trials, temperature 0.246), best score: 0.341
# icet.target_cluster_vector_annealing: INFO  MC step 36000/60000 (15647 accepted trials, temperature 0.233), best score: 0.297
# icet.target_cluster_vector_annealing: INFO  MC step 37000/60000 (15869 accepted trials, temperature 0.221), best score: 0.297
# icet.target_cluster_vector_annealing: INFO  MC step 38000/60000 (16081 accepted trials, temperature 0.209), best score: 0.297
# icet.target_cluster_vector_annealing: INFO  MC step 39000/60000 (16287 accepted trials, temperature 0.197), best score: 0.297
# icet.target_cluster_vector_annealing: INFO  MC step 40000/60000 (16462 accepted trials, temperature 0.185), best score: 0.091
# icet.target_cluster_vector_annealing: INFO  MC step 41000/60000 (16625 accepted trials, temperature 0.174), best score: 0.091
# icet.target_cluster_vector_annealing: INFO  MC step 42000/60000 (16788 accepted trials, temperature 0.163), best score: 0.091
# icet.target_cluster_vector_annealing: INFO  MC step 43000/60000 (16937 accepted trials, temperature 0.152), best score: 0.091
# icet.target_cluster_vector_annealing: INFO  MC step 44000/60000 (17053 accepted trials, temperature 0.142), best score: -0.015
# icet.target_cluster_vector_annealing: INFO  MC step 45000/60000 (17191 accepted trials, temperature 0.132), best score: -0.020
# icet.target_cluster_vector_annealing: INFO  MC step 46000/60000 (17307 accepted trials, temperature 0.122), best score: -0.020
# icet.target_cluster_vector_annealing: INFO  MC step 47000/60000 (17424 accepted trials, temperature 0.112), best score: -0.020
# icet.target_cluster_vector_annealing: INFO  MC step 48000/60000 (17513 accepted trials, temperature 0.102), best score: -0.020
# icet.target_cluster_vector_annealing: INFO  MC step 49000/60000 (17602 accepted trials, temperature 0.093), best score: -0.231
# icet.target_cluster_vector_annealing: INFO  MC step 50000/60000 (17672 accepted trials, temperature 0.084), best score: -0.231
# icet.target_cluster_vector_annealing: INFO  MC step 51000/60000 (17715 accepted trials, temperature 0.075), best score: -0.340
# icet.target_cluster_vector_annealing: INFO  MC step 52000/60000 (17741 accepted trials, temperature 0.066), best score: -0.418
# icet.target_cluster_vector_annealing: INFO  MC step 53000/60000 (17763 accepted trials, temperature 0.057), best score: -0.418
# icet.target_cluster_vector_annealing: INFO  MC step 54000/60000 (17790 accepted trials, temperature 0.049), best score: -0.418
# icet.target_cluster_vector_annealing: INFO  MC step 55000/60000 (17799 accepted trials, temperature 0.041), best score: -0.578
# icet.target_cluster_vector_annealing: INFO  MC step 56000/60000 (17801 accepted trials, temperature 0.032), best score: -0.640
# icet.target_cluster_vector_annealing: INFO  MC step 57000/60000 (17801 accepted trials, temperature 0.024), best score: -0.640
# icet.target_cluster_vector_annealing: INFO  MC step 58000/60000 (17801 accepted trials, temperature 0.016), best score: -0.640
# icet.target_cluster_vector_annealing: INFO  MC step 59000/60000 (17801 accepted trials, temperature 0.009), best score: -0.640
# icet.orbit_list: INFO  Done getting matrix_of_equivalent_positions.
# icet.orbit_list: INFO  Done getting neighbor lists.
# icet.orbit_list: INFO  Transformation of matrix of equivalent positions to lattice neighbor format completed.
# icet.orbit_list: INFO  Finished construction of orbit list.
# icet.target_cluster_vector_annealing: INFO  Initializing target cluster vector annealing with 1 supercells
# icet.target_cluster_vector_annealing: INFO  MC step 0/60000 (0 accepted trials, temperature 5.000), best score: 4.688
# icet.target_cluster_vector_annealing: INFO  MC step 1000/60000 (884 accepted trials, temperature 1.861), best score: 0.621
# icet.target_cluster_vector_annealing: INFO  MC step 2000/60000 (1707 accepted trials, temperature 1.546), best score: 0.360
# icet.target_cluster_vector_annealing: INFO  MC step 3000/60000 (2493 accepted trials, temperature 1.362), best score: 0.058
# icet.target_cluster_vector_annealing: INFO  MC step 4000/60000 (3256 accepted trials, temperature 1.231), best score: 0.058
# icet.target_cluster_vector_annealing: INFO  MC step 5000/60000 (3939 accepted trials, temperature 1.130), best score: 0.058
# icet.target_cluster_vector_annealing: INFO  MC step 6000/60000 (4600 accepted trials, temperature 1.047), best score: -0.034
# icet.target_cluster_vector_annealing: INFO  MC step 7000/60000 (5182 accepted trials, temperature 0.977), best score: -0.034
# icet.target_cluster_vector_annealing: INFO  MC step 8000/60000 (5768 accepted trials, temperature 0.917), best score: -0.034
# icet.target_cluster_vector_annealing: INFO  MC step 9000/60000 (6313 accepted trials, temperature 0.863), best score: -0.034
# icet.target_cluster_vector_annealing: INFO  MC step 10000/60000 (6938 accepted trials, temperature 0.815), best score: -0.034
# icet.target_cluster_vector_annealing: INFO  MC step 11000/60000 (7521 accepted trials, temperature 0.772), best score: -0.034
# icet.target_cluster_vector_annealing: INFO  MC step 12000/60000 (7991 accepted trials, temperature 0.732), best score: -0.034
# icet.target_cluster_vector_annealing: INFO  MC step 13000/60000 (8436 accepted trials, temperature 0.696), best score: -0.034
# icet.target_cluster_vector_annealing: INFO  MC step 14000/60000 (8871 accepted trials, temperature 0.662), best score: -0.034
# icet.target_cluster_vector_annealing: INFO  MC step 15000/60000 (9343 accepted trials, temperature 0.631), best score: -0.034
# icet.target_cluster_vector_annealing: INFO  MC step 16000/60000 (9841 accepted trials, temperature 0.602), best score: -0.097
# icet.target_cluster_vector_annealing: INFO  MC step 17000/60000 (10207 accepted trials, temperature 0.574), best score: -0.097
# icet.target_cluster_vector_annealing: INFO  MC step 18000/60000 (10589 accepted trials, temperature 0.548), best score: -0.097
# icet.target_cluster_vector_annealing: INFO  MC step 19000/60000 (11014 accepted trials, temperature 0.523), best score: -0.097
# icet.target_cluster_vector_annealing: INFO  MC step 20000/60000 (11393 accepted trials, temperature 0.500), best score: -0.097
# icet.target_cluster_vector_annealing: INFO  MC step 21000/60000 (11783 accepted trials, temperature 0.478), best score: -0.097
# icet.target_cluster_vector_annealing: INFO  MC step 22000/60000 (12138 accepted trials, temperature 0.457), best score: -0.097
# icet.target_cluster_vector_annealing: INFO  MC step 23000/60000 (12484 accepted trials, temperature 0.437), best score: -0.097
# icet.target_cluster_vector_annealing: INFO  MC step 24000/60000 (12792 accepted trials, temperature 0.417), best score: -0.097
# icet.target_cluster_vector_annealing: INFO  MC step 25000/60000 (13118 accepted trials, temperature 0.399), best score: -0.097
# icet.target_cluster_vector_annealing: INFO  MC step 26000/60000 (13427 accepted trials, temperature 0.381), best score: -0.097
# icet.target_cluster_vector_annealing: INFO  MC step 27000/60000 (13734 accepted trials, temperature 0.364), best score: -0.097
# icet.target_cluster_vector_annealing: INFO  MC step 28000/60000 (14016 accepted trials, temperature 0.347), best score: -0.097
# icet.target_cluster_vector_annealing: INFO  MC step 29000/60000 (14283 accepted trials, temperature 0.331), best score: -0.097
# icet.target_cluster_vector_annealing: INFO  MC step 30000/60000 (14564 accepted trials, temperature 0.316), best score: -0.097
# icet.target_cluster_vector_annealing: INFO  MC step 31000/60000 (14828 accepted trials, temperature 0.301), best score: -0.097
# icet.target_cluster_vector_annealing: INFO  MC step 32000/60000 (15109 accepted trials, temperature 0.287), best score: -0.097
# icet.target_cluster_vector_annealing: INFO  MC step 33000/60000 (15393 accepted trials, temperature 0.273), best score: -0.254
# icet.target_cluster_vector_annealing: INFO  MC step 34000/60000 (15638 accepted trials, temperature 0.259), best score: -0.254
# icet.target_cluster_vector_annealing: INFO  MC step 35000/60000 (15881 accepted trials, temperature 0.246), best score: -0.265
# icet.target_cluster_vector_annealing: INFO  MC step 36000/60000 (16108 accepted trials, temperature 0.233), best score: -0.265
# icet.target_cluster_vector_annealing: INFO  MC step 37000/60000 (16327 accepted trials, temperature 0.221), best score: -0.418
# icet.target_cluster_vector_annealing: INFO  MC step 38000/60000 (16576 accepted trials, temperature 0.209), best score: -0.418
# icet.target_cluster_vector_annealing: INFO  MC step 39000/60000 (16789 accepted trials, temperature 0.197), best score: -0.472
# icet.target_cluster_vector_annealing: INFO  MC step 40000/60000 (17021 accepted trials, temperature 0.185), best score: -0.472
# icet.target_cluster_vector_annealing: INFO  MC step 41000/60000 (17219 accepted trials, temperature 0.174), best score: -0.472
# icet.target_cluster_vector_annealing: INFO  MC step 42000/60000 (17408 accepted trials, temperature 0.163), best score: -0.472
# icet.target_cluster_vector_annealing: INFO  MC step 43000/60000 (17578 accepted trials, temperature 0.152), best score: -0.472
# icet.target_cluster_vector_annealing: INFO  MC step 44000/60000 (17733 accepted trials, temperature 0.142), best score: -0.472
# icet.target_cluster_vector_annealing: INFO  MC step 45000/60000 (17895 accepted trials, temperature 0.132), best score: -0.472
# icet.target_cluster_vector_annealing: INFO  MC step 46000/60000 (18026 accepted trials, temperature 0.122), best score: -0.472
# icet.target_cluster_vector_annealing: INFO  MC step 47000/60000 (18184 accepted trials, temperature 0.112), best score: -0.472
# icet.target_cluster_vector_annealing: INFO  MC step 48000/60000 (18279 accepted trials, temperature 0.102), best score: -0.504
# icet.target_cluster_vector_annealing: INFO  MC step 49000/60000 (18382 accepted trials, temperature 0.093), best score: -0.504
# icet.target_cluster_vector_annealing: INFO  MC step 50000/60000 (18431 accepted trials, temperature 0.084), best score: -0.703
# icet.target_cluster_vector_annealing: INFO  MC step 51000/60000 (18451 accepted trials, temperature 0.075), best score: -0.961
# icet.target_cluster_vector_annealing: INFO  MC step 52000/60000 (18462 accepted trials, temperature 0.066), best score: -0.961
# icet.target_cluster_vector_annealing: INFO  MC step 53000/60000 (18483 accepted trials, temperature 0.057), best score: -0.961
# icet.target_cluster_vector_annealing: INFO  MC step 54000/60000 (18502 accepted trials, temperature 0.049), best score: -0.961
# icet.target_cluster_vector_annealing: INFO  MC step 55000/60000 (18521 accepted trials, temperature 0.041), best score: -0.961
# icet.target_cluster_vector_annealing: INFO  MC step 56000/60000 (18536 accepted trials, temperature 0.032), best score: -1.327
# icet.target_cluster_vector_annealing: INFO  MC step 57000/60000 (18538 accepted trials, temperature 0.024), best score: -1.514
# icet.target_cluster_vector_annealing: INFO  MC step 58000/60000 (18540 accepted trials, temperature 0.016), best score: -1.514
# icet.target_cluster_vector_annealing: INFO  MC step 59000/60000 (18541 accepted trials, temperature 0.009), best score: -1.514
# icet.orbit_list: INFO  Done getting matrix_of_equivalent_positions.
# icet.orbit_list: INFO  Done getting neighbor lists.
# icet.orbit_list: INFO  Transformation of matrix of equivalent positions to lattice neighbor format completed.
# icet.orbit_list: INFO  Finished construction of orbit list.
# icet.target_cluster_vector_annealing: INFO  Initializing target cluster vector annealing with 1 supercells
# icet.target_cluster_vector_annealing: INFO  MC step 0/60000 (0 accepted trials, temperature 5.000), best score: 0.278
# icet.target_cluster_vector_annealing: INFO  MC step 1000/60000 (840 accepted trials, temperature 1.861), best score: -0.895
# icet.target_cluster_vector_annealing: INFO  MC step 2000/60000 (1658 accepted trials, temperature 1.546), best score: -0.895
# icet.target_cluster_vector_annealing: INFO  MC step 3000/60000 (2325 accepted trials, temperature 1.362), best score: -0.958
# icet.target_cluster_vector_annealing: INFO  MC step 4000/60000 (3018 accepted trials, temperature 1.231), best score: -1.015
# icet.target_cluster_vector_annealing: INFO  MC step 5000/60000 (3699 accepted trials, temperature 1.130), best score: -1.015
# icet.target_cluster_vector_annealing: INFO  MC step 6000/60000 (4345 accepted trials, temperature 1.047), best score: -1.015
# icet.target_cluster_vector_annealing: INFO  MC step 7000/60000 (4929 accepted trials, temperature 0.977), best score: -1.082
# icet.target_cluster_vector_annealing: INFO  MC step 8000/60000 (5474 accepted trials, temperature 0.917), best score: -1.203
# icet.target_cluster_vector_annealing: INFO  MC step 9000/60000 (6010 accepted trials, temperature 0.863), best score: -1.203
# icet.target_cluster_vector_annealing: INFO  MC step 10000/60000 (6485 accepted trials, temperature 0.815), best score: -1.203
# icet.target_cluster_vector_annealing: INFO  MC step 11000/60000 (6982 accepted trials, temperature 0.772), best score: -1.203
# icet.target_cluster_vector_annealing: INFO  MC step 12000/60000 (7467 accepted trials, temperature 0.732), best score: -1.203
# icet.target_cluster_vector_annealing: INFO  MC step 13000/60000 (7962 accepted trials, temperature 0.696), best score: -1.203
# icet.target_cluster_vector_annealing: INFO  MC step 14000/60000 (8449 accepted trials, temperature 0.662), best score: -1.203
# icet.target_cluster_vector_annealing: INFO  MC step 15000/60000 (8887 accepted trials, temperature 0.631), best score: -1.305
# icet.target_cluster_vector_annealing: INFO  MC step 16000/60000 (9315 accepted trials, temperature 0.602), best score: -1.305
# icet.target_cluster_vector_annealing: INFO  MC step 17000/60000 (9732 accepted trials, temperature 0.574), best score: -1.305
# icet.target_cluster_vector_annealing: INFO  MC step 18000/60000 (10209 accepted trials, temperature 0.548), best score: -1.305
# icet.target_cluster_vector_annealing: INFO  MC step 19000/60000 (10618 accepted trials, temperature 0.523), best score: -1.305
# icet.target_cluster_vector_annealing: INFO  MC step 20000/60000 (11053 accepted trials, temperature 0.500), best score: -1.305
# icet.target_cluster_vector_annealing: INFO  MC step 21000/60000 (11456 accepted trials, temperature 0.478), best score: -1.305
# icet.target_cluster_vector_annealing: INFO  MC step 22000/60000 (11818 accepted trials, temperature 0.457), best score: -1.305
# icet.target_cluster_vector_annealing: INFO  MC step 23000/60000 (12143 accepted trials, temperature 0.437), best score: -1.305
# icet.target_cluster_vector_annealing: INFO  MC step 24000/60000 (12552 accepted trials, temperature 0.417), best score: -1.305
# icet.target_cluster_vector_annealing: INFO  MC step 25000/60000 (12888 accepted trials, temperature 0.399), best score: -1.305
# icet.target_cluster_vector_annealing: INFO  MC step 26000/60000 (13256 accepted trials, temperature 0.381), best score: -1.305
# icet.target_cluster_vector_annealing: INFO  MC step 27000/60000 (13589 accepted trials, temperature 0.364), best score: -1.305
# icet.target_cluster_vector_annealing: INFO  MC step 28000/60000 (13917 accepted trials, temperature 0.347), best score: -1.313
# icet.target_cluster_vector_annealing: INFO  MC step 29000/60000 (14244 accepted trials, temperature 0.331), best score: -1.313
# icet.target_cluster_vector_annealing: INFO  MC step 30000/60000 (14529 accepted trials, temperature 0.316), best score: -1.313
# icet.target_cluster_vector_annealing: INFO  MC step 31000/60000 (14796 accepted trials, temperature 0.301), best score: -1.313
# icet.target_cluster_vector_annealing: INFO  MC step 32000/60000 (15086 accepted trials, temperature 0.287), best score: -1.313
# icet.target_cluster_vector_annealing: INFO  MC step 33000/60000 (15380 accepted trials, temperature 0.273), best score: -1.313
# icet.target_cluster_vector_annealing: INFO  MC step 34000/60000 (15656 accepted trials, temperature 0.259), best score: -1.313
# icet.target_cluster_vector_annealing: INFO  MC step 35000/60000 (15923 accepted trials, temperature 0.246), best score: -1.313
# icet.target_cluster_vector_annealing: INFO  MC step 36000/60000 (16219 accepted trials, temperature 0.233), best score: -1.313
# icet.target_cluster_vector_annealing: INFO  MC step 37000/60000 (16486 accepted trials, temperature 0.221), best score: -1.313
# icet.target_cluster_vector_annealing: INFO  MC step 38000/60000 (16768 accepted trials, temperature 0.209), best score: -1.313
# icet.target_cluster_vector_annealing: INFO  MC step 39000/60000 (16983 accepted trials, temperature 0.197), best score: -1.313
# icet.target_cluster_vector_annealing: INFO  MC step 40000/60000 (17196 accepted trials, temperature 0.185), best score: -1.313
# icet.target_cluster_vector_annealing: INFO  MC step 41000/60000 (17431 accepted trials, temperature 0.174), best score: -1.313
# icet.target_cluster_vector_annealing: INFO  MC step 42000/60000 (17649 accepted trials, temperature 0.163), best score: -2.351
# icet.target_cluster_vector_annealing: INFO  MC step 43000/60000 (17662 accepted trials, temperature 0.152), best score: -2.538
# icet.target_cluster_vector_annealing: INFO  MC step 44000/60000 (17818 accepted trials, temperature 0.142), best score: -2.538
# icet.target_cluster_vector_annealing: INFO  MC step 45000/60000 (17985 accepted trials, temperature 0.132), best score: -2.538
# icet.target_cluster_vector_annealing: INFO  MC step 46000/60000 (18155 accepted trials, temperature 0.122), best score: -2.538
# icet.target_cluster_vector_annealing: INFO  MC step 47000/60000 (18319 accepted trials, temperature 0.112), best score: -2.538
# icet.target_cluster_vector_annealing: INFO  MC step 48000/60000 (18434 accepted trials, temperature 0.102), best score: -2.538
# icet.target_cluster_vector_annealing: INFO  MC step 49000/60000 (18472 accepted trials, temperature 0.093), best score: -2.538
# icet.target_cluster_vector_annealing: INFO  MC step 50000/60000 (18490 accepted trials, temperature 0.084), best score: -2.538
# icet.target_cluster_vector_annealing: INFO  MC step 51000/60000 (18504 accepted trials, temperature 0.075), best score: -2.661
# icet.target_cluster_vector_annealing: INFO  MC step 52000/60000 (18518 accepted trials, temperature 0.066), best score: -2.723
# icet.target_cluster_vector_annealing: INFO  MC step 53000/60000 (18539 accepted trials, temperature 0.057), best score: -2.723
# icet.target_cluster_vector_annealing: INFO  MC step 54000/60000 (18552 accepted trials, temperature 0.049), best score: -2.723
# icet.target_cluster_vector_annealing: INFO  MC step 55000/60000 (18557 accepted trials, temperature 0.041), best score: -2.723
# icet.target_cluster_vector_annealing: INFO  MC step 56000/60000 (18563 accepted trials, temperature 0.032), best score: -2.723
# icet.target_cluster_vector_annealing: INFO  MC step 57000/60000 (18568 accepted trials, temperature 0.024), best score: -2.723
# icet.target_cluster_vector_annealing: INFO  MC step 58000/60000 (18569 accepted trials, temperature 0.016), best score: -2.723
# icet.target_cluster_vector_annealing: INFO  MC step 59000/60000 (18569 accepted trials, temperature 0.009), best score: -2.723
