# %%
from pdyna.core import Frame
import numpy as np

frame1 = Frame("poscar", "CONTCAR")

frame1.analysis()
avg_tilt = np.abs(frame1.Tilting).mean(axis=0)
# Out:
# ------------------------------------------------------------
# Loading Frame files...
# Current sample: test
#
# Computing octahedral tilting and distortion...
# Octahedral distortions: [0.0264 0.     0.0168 0.0995]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 6
#       2 import numpy as np
#       4 frame1 = Frame("poscar", "CONTCAR")
# ----> 6 frame1.analysis()
#       7 avg_tilt = np.abs(frame1.Tilting).mean(axis=0)
#
# File ~/miniconda3/envs/sqs/lib/python3.10/site-packages/pdyna/core.py:3828, in Frame.analysis(self, uniname, saveFigures, align_rotation, tilt_corr_spatial, max_tilt_of_plot)
#    3824 self.timing["env_resolve"] = et1-et0
#    3827 print("Computing octahedral tilting and distortion...")
# -> 3828 self.tilting_and_distortion(uniname=uniname,saveFigures=saveFigures,tilt_corr_spatial=tilt_corr_spatial,max_tilt_of_plot=max_tilt_of_plot)
# ...
