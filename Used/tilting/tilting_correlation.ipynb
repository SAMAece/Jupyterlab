# %%
from pdyna.core import Frame
import numpy as np

frame1 = Frame("poscar", "CONTCAR_Br6I6")

frame1.analysis()
avg_tilt = np.abs(frame1.Tilting).mean(axis=0)
# Out:
# ------------------------------------------------------------
# Loading Frame files...
# Current sample: test
#
# Computing octahedral tilting and distortion...
# Octahedral distortions: [0.0411 0.0785 0.0602 0.144 ]
# tilting correlation: [-0.681 -0.528  0.508]
#
#
# --Elapsed Time
# Data Reading:          00:00:00
# Structure Resolving:   00:00:00
# Tilting & Distortion:  00:00:01
# Total:                 00:00:01
# ------------------------------------------------------------
