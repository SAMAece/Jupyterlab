# %%
from pdyna.core import Frame
import numpy as np

frame1 = Frame("poscar", "CONTCAR_Br")

frame1.analysis()
avg_tilt = np.abs(frame1.Tilting).mean(axis=0)

print("average tilt angle =", avg_tilt)
# Out:
# ------------------------------------------------------------
# Loading Frame files...
# Current sample: test
#
# Computing octahedral tilting and distortion...
# Octahedral distortions: [0.0373 0.0838 0.0746 0.1343]
# tilting correlation: [ 0.03   0.012 -0.692]
#
#
# --Elapsed Time
# Data Reading:          00:00:00
# Structure Resolving:   00:00:00
# Tilting & Distortion:  00:00:00
# Total:                 00:00:00
# ------------------------------------------------------------
# average tilt angle = [2.66779296 2.63008121 1.88951785]

# %%
\begin{table}[]
\centering
\caption{}
\label{tab:my-table}
\begin{tabular}{lll|l}
\hline
\multicolumn{1}{c}{}                           & Tilt class & Tilts  & Space group \\
\multicolumn{1}{c}{$\ce{FAPb(Br1/12I11/12)3}$} & [-1 -1 0]  & a-a-b0 &             \\
$\ce{FAPb(Br2/12I10/12)3}$                     & [-1 -1 0]  & a-a-b- &             \\ \hline
$\ce{FAPb(Br3/12I9/12)3}$                      & [0 0 0]    & a0b-a+ &             \\
$\ce{FAPb(Br4/12I8/12)3}$                      & [-1 0 0]   & a-b0c+ &             \\
$\ce{FAPb(Br5/12I7/12)3}$                      & [-1 0 0]   & a-b0c+ &             \\ \hline
$\ce{FAPb(Br6/12I6/12)3}$                      & [-1 -1 1]  & a-b-c+ &             \\
$\ce{FAPb(Br7/12I5/12)3}$                      & [-1 0 0]   & a-b-c+ &             \\
$\ce{FAPb(Br8/12I4/12)3}$                      & [0 0 0]    & a0a0b+ &             \\ \hline
$\ce{FAPb(Br9/12I3/12)3}$                      & [0 -1 0]   & a+b-c- &             \\
$\ce{FAPb(Br10/12I2/12)3}$                     & [0 0 0]    & a0a0a0 &             \\
$\ce{FAPb(Br11/12I1/12)3}$                     & [0 0 -1]   & a-a-b- &            
\end{tabular}
\end{table}
# Out:
#   Cell In[2], line 1
#     \begin{table}[]
#      ^
# SyntaxError: unexpected character after line continuation character
